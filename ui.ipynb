# %% [markdown]
# # ATAP LLM Classifier

# %%
import panel as pn
from panel.theme import Material

pn.extension()
pn.config.design = Material

# %%
from atap_llm_classifier.views.main import MainWidget

MainWidget()
